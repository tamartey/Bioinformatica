# %%
pip install biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 2.8 MB/s eta 0:00:00 MB/s eta 0:00:01:010m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print('type shit')
# Out:
# type shit
